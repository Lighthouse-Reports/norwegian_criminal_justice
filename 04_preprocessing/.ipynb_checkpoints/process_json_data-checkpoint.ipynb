# %% [markdown]
# Script: Preprocess Data
# Author: Gabriel Geiger
# Date: 17-01-2024
# <br>
#
# Description: <br>
# @input: Raw json files representing databases containing judgements, defendants and lay judges.
# @output: A merged dataframe where all nested data is flattened. Each row is a defendant with their corresponding case data (outcome, lay judges etc.)

# %%
import pandas as pd 
import warnings
import numpy as np 
import os
from pathlib import Path

warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# Get the notebook's directory
notebook_path = os.path.abspath('')+'/..'
os.chdir(notebook_path)

# %%
print(os.getcwd())
# Out:
# /Users

# %% [markdown]
# Load Defendants

# %%
def load_defendants(file:str) -> pd.DataFrame : 
    df = pd.read_json(file)
    return df

defendant_df = load_defendants(os.getcwd() + "/00_raw_data/hidden/lr_tiltalte.json")

# Extract ID for defendants 
defendant_df["_id"] = defendant_df["_id"].apply(lambda id_dict: id_dict["$oid"])

# Add defendant prefix to all columns to avoid column collision with lay judges 
defendant_df = defendant_df.add_prefix("defendant_")


print("Defendant dataframe shape",defendant_df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 5
#       2     df = pd.read_json(file)
#       3     return df
# ----> 5 defendant_df = load_defendants(os.getcwd() + "/00_raw_data/hidden/lr_tiltalte.json")
#       7 # Extract ID for defendants
#       8 defendant_df["_id"] = defendant_df["_id"].apply(lambda id_dict: id_dict["$oid"])
#
# Cell In[13], line 2, in load_defendants(file)
#       1 def load_defendants(file:str) -> pd.DataFrame :
# ----> 2     df = pd.read_json(file)
#       3     return df
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/io/json/_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
#     799     precise_float=precise_float,
#     800     date_unit=date_unit,
#     801     encoding=encoding,
#     802     lines=lines,
#     803     chunksize=chunksize,
#     804     compression=compression,
#     805     nrows=nrows,
#     806     storage_options=storage_options,
#     807     encoding_errors=encoding_errors,
#     808     dtype_backend=dtype_backend,
#     809     engine=engine,
#     810 )
#     812 if chunksize:
#     813     return json_reader
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/io/json/_json.py:904, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     902     self.data = filepath_or_buffer
#     903 elif self.engine == "ujson":
# --> 904     data = self._get_data_from_filepath(filepath_or_buffer)
#     905     self.data = self._preprocess_data(data)
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/io/json/_json.py:960, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     952     filepath_or_buffer = self.handles.handle
#     953 elif (
#     954     isinstance(filepath_or_buffer, str)
#     955     and filepath_or_buffer.lower().endswith(
#    (...)
#     958     and not file_exists(filepath_or_buffer)
#     959 ):
# --> 960     raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     961 else:
#     962     warnings.warn(
#     963         "Passing literal json to 'read_json' is deprecated and "
#     964         "will be removed in a future version. To read from a "
#    (...)
#     967         stacklevel=find_stack_level(),
#     968     )
#
# FileNotFoundError: File /Users/justin-casimirbraun/GitHub/00_raw_data/hidden/lr_tiltalte.json does not exist

# %% [markdown]
# Load Cases

# %%
def load_cases(file:str) -> pd.DataFrame : 
    df = pd.read_json(file)

    return df

cases_df = load_cases(os.getcwd() + "/00_raw_data/hidden/lr_dommer.json")

# Extract id for cases 
cases_df["_id"] = cases_df["_id"].apply(
    lambda id : id["$oid"]
)

print("Case Dataframe shape",cases_df.shape)
# Out:
# Case Dataframe shape (9019, 8)

# %% [markdown]
# Case Data Validation
#
# Run data validation steps and throw out any rows that violate business rules.

# %%
# All cases should have a judgement, drop any that do not. 
length_before = len(cases_df)
cases_df.dropna(subset=["dom"],inplace=True)
print("{n} cases have been dropped because they did not have a judgement.".format(n=length_before - len(cases_df)))

# All cases should have one judge, drop any that do not. 
length_before = len(cases_df)
cases_df.dropna(subset=["fagdommere"],inplace=True)
cases_df = cases_df[cases_df["fagdommere"].apply(
    lambda judge_array: len(judge_array) == 1)
]

# There appears to have been some parsing on the Norwegians-side. 
cases_df = cases_df[cases_df["fagdommere"].apply(
    lambda judge_array : type(judge_array) == list
)]
print("{n} cases have been dropped because they did not have one judge.".format(n=length_before - len(cases_df)))

# All cases should have two lay judges, drop any that do not. 
length_before = len(cases_df)
cases_df.dropna(subset=["meddommere"],inplace=True)
cases_df = cases_df[cases_df["meddommere"].apply(
    lambda lay_array: len(lay_array) == 2)
]
print("{n} cases have been dropped because they did not have two lay judges.".format(n=length_before - len(cases_df)))

# All cases should have at least one defendant
length_before = len(cases_df)
cases_df.dropna(subset=["tiltalte"],inplace=True)
cases_df = cases_df[cases_df["tiltalte"].apply(
    lambda lay_array: len(lay_array) > 0)
]
print("{n} cases have been dropped because they did not have a defendant.".format(n=length_before - len(cases_df)))

# Reset the index. 
cases_df.reset_index(inplace=True)

print("Shape",cases_df.shape)
# Out:
# 78 cases have been dropped because they did not have a judgement.
# 127 cases have been dropped because they did not have one judge.
# 36 cases have been dropped because they did not have two lay judges.
# 11 cases have been dropped because they did not have a defendant.
# Shape (8767, 9)

# %% [markdown]
# Match Cases with Courts

# %%
court_df = pd.read_json("00_raw_data/hidden/lr_filnavn.json")
court_df["_id"] = court_df["_id"].apply(lambda id_dict : id_dict["$oid"])

court_df["court_code"] = court_df["filnavn"].apply( 
    lambda filename : filename.split("-")[2].upper()
)

court_names = pd.read_csv("00_raw_data/shortnames_districtcourts.csv",delimiter=";")
court_names.rename(columns={"Short name":"court_code"},inplace=True)

court_df = pd.merge(court_df,court_names,on="court_code",how="left")
court_df["District Court"].fillna(court_df["court_code"],inplace=True)

court_df["District Court"] = court_df["District Court"].apply(
    lambda court_name : court_name if "tingrett" in court_name else "Unknown"
)
court_df.rename(columns={"District Court":"case_district_court"},inplace=True)

cases_df = pd.merge(cases_df,court_df,on="_id",how="left")

# %% [markdown]
# Merge Case DataFrame with Defendants DataFrame
#
# Each defendant in the defendant database has an ID. Each case in the case dataframe has an array of defendant ids. Ultimately we want each row in our final dataframe to be a defendant and their corresponding case.

# %%
"""
Takes the raw 
"""
def parse_defendant_ids(raw_defendant_data:dict) -> list : 
    defendant_ids = []

    for defendant in raw_defendant_data : 
        if "motpart_id" in defendant : 
            if "$oid" in defendant["motpart_id"] : 
                defendant_ids.append(defendant["motpart_id"]['$oid'])
        
    
    return defendant_ids
        
# Create a clean list of defendant ids associated with the case 
cases_df["defendant_ids"] = cases_df["tiltalte"].apply(parse_defendant_ids)

# Explode the 'defendant_ids' column in cases_df to create separate rows for each defendant
cases_exploded = cases_df.explode('defendant_ids')

# Merge the exploded cases_df with defendants_df based on defendant_id
merged_df = pd.merge(cases_exploded, defendant_df, left_on='defendant_ids', right_on='defendant__id', how='left',suffixes=('_case', '_defendant'))
merged_df.reset_index(inplace=True,drop=True)

# Drop all cases without a defendant. Unfortunately not every defendant has an ID 
length_before = len(merged_df)
merged_df.dropna(subset=["defendant__id"],inplace=True)
merged_df.reset_index(inplace=True,drop=True)
print("{i} rows have been dropped because no matching defendant was found.".format(i=length_before - len(merged_df)))

print("Shape",merged_df.shape)
# Out:
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 120}, 'dømt': [['Straffeloven §331', ['Straffeloven §330', 'Straffeloven §16']]]}, {'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 115}, 'dømt': [['Straffeloven §231'], ['Straffeloven §181'], ['Straffeloven §298'], ['Straffeloven §263'], ['Straffeloven §156'], ['Straffeloven §155'], ['Politiloven §30'], ['Straffeloven §271']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'forvaring': 'true'}, 'dømt': [['Straffeloven §293', ['Straffeloven §291']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 45}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 45}, 'dømt': [['Straffeloven §330', ['Straffeloven §16']], ['Straffeloven §327', ['Straffeloven §15']], ['Straffeloven §79'], ['Straffeloven §83']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 45}, 'dømt': [['Straffeloven §327', ['Straffeloven §15']], ['Straffeloven §351'], ['Straffeloven §263'], ['Straffeloven §231'], ['Straffeloven §79'], ['Straffeloven §83']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30}, 'dømt': [['Straffeloven §231', ['Straffeloven §15']], ['Straffeloven §321', ['Straffeloven §15']]]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 30}, 'dømt': [['Straffeloven §231', ['Straffeloven §15']], ['Straffeloven §321', ['Straffeloven §15']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 210}, 'dømt': [['Verdipapirhandelloven §17']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 210}, 'dømt': [['Verdipapirhandelloven §17']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 90, 'betinget': 'true'}, 'dømt': [['Verdipapirhandelloven §17']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 90, 'betinget': 'true'}, 'dømt': [['Verdipapirhandelloven §17']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 150, 'samfunnsstraff_timer': 144, 'samfunnsstraff_gjennomføringstid_dager': 150, 'bot': 7000}, 'dømt': [['Straffeloven §322', ['Straffeloven §321']], ['Straffeloven §321'], ['Straffeloven §231', ['Straffeloven §16']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §5', 'Skiltforskriften §8']], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §79']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'bot': 400000}, 'dømt': [['Kulturminneloven §27', ['Kulturminneloven §9', 'Straffeloven §27']], ['Kulturminneloven §27', ['Kulturminneloven §3', 'Straffeloven §27']], ['Kulturminneloven §27', ['Kulturminneloven §25', 'Straffeloven §27']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 900}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 15}}, {'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 15}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 720}, 'dømt': [['Straffeloven §372', ['Straffeloven §371']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 90, 'betinget': 'delvis', 'fengsel_dager_betinget': '45'}, 'dømt': [['Straffeloven §351', ['Straffeloven §15']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §271'], ['Straffeloven §156'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 540, 'betinget': 'delvis', 'fengsel_dager_betinget': 390}, 'dømt': [['Straffeloven §231'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §10']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §17']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §332'], ['Straffeloven §361'], ['Straffeloven §342'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §5', 'Skiltforskriften §8']], ['Straffeloven §189'], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §79'], ['Vegtrafikkloven §24']], 'frifunnet': [['Straffeloven §231'], ['Straffeloven §321'], ['Straffeloven §268', ['Straffeloven §15']], ['Straffeloven §321', ['Straffeloven §16', 'Straffeloven §15']], ['Straffeloven §321', ['Straffeloven §15']], ['Straffeloven §231', ['Straffeloven §15']], ['Straffeloven §351'], ['Straffeloven §351', ['Straffeloven §15']], ['Våpenloven §33', ['Våpenloven §31', 'Våpenforskriften §80']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 90}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 100}, 'dømt': [['Straffeloven §155'], ['Straffeloven §271'], ['Straffeloven §351'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'fengsel_subsidiært_dager': 150, 'bot': 5000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Straffeloven §322', ['Straffeloven §321']], ['Straffeloven §322', ['Straffeloven §321', 'Straffeloven §16']], ['Våpenloven §33', ['Våpenloven §8']], ['Våpenloven §33', ['Våpenloven §11']], ['Straffeloven §170'], ['Politiloven §30'], ['Straffeloven §169'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Bilansvarsloven §20'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §17']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 150, 'bot': 52000}, 'dømt': [['Straffeloven §273'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §17']]], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'dømt': []}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1980}, 'dømt': [['Straffeloven §372', ['Straffeloven §371']]], 'motpart_id': ''}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 210}, 'dømt': [['Straffeloven §273'], ['Straffeloven §271'], ['Straffeloven §321'], ['Straffeloven §268', ['Straffeloven §16']], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §274', ['Straffeloven §273']], ['Straffeloven §155'], ['Straffeloven §265'], ['Straffeloven §231'], ['Straffeloven §271'], ['Straffeloven §189'], ['Straffeloven §351'], ['Straffeloven §263'], ['Brann- og eksplosjonsvernloven §42', ['Brann- og eksplosjonsvernloven §5']], ['Straffeloven §62']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 14}, 'dømt': [['Luftfartsloven §14']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 4680}, 'dømt': [['Straffeloven §275'], ['Dyrevelferdsloven §37']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 15, 'samfunnsstraff_timer': 362, 'samfunnsstraff_gjennomføringstid_dager': 360, 'bot': 5000}, 'dømt': [['Straffeloven §232', ['Straffeloven §231']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §79']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 25, 'bot': 18000}}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §333', ['Straffeloven §332']], ['Straffeloven §67']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 10}, 'dømt': [['Straffeloven §321']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 120}, 'dømt': [['Straffeloven §281'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 30, 'samfunnsstraff_timer': 30, 'samfunnsstraff_gjennomføringstid_dager': 120}, 'dømt': [['Straffeloven §231'], ['Straffeloven §189'], ['Straffeloven §232', ['Straffeloven §321']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 660}, 'dømt': [['Straffeloven §232', ['Straffeloven §231']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21, 'fengsel_subsidiært_dager': 15, 'betinget': 'true'}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Straffeloven §54'], ['Straffeloven §55'], ['Vegtrafikkloven §33']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 990}, 'dømt': [['Straffeloven §372', ['Straffeloven §371']], ['Straffeloven §338', ['Straffeloven §337']], ['Straffeloven §221']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1140, 'betinget': 'delvis', 'fengsel_dager_betinget': 780}, 'dømt': [['Straffeloven §232', ['Straffeloven §231']], ['Straffeloven §231'], ['Straffeloven §79'], ['Straffeloven §34']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 270, 'fengsel_subsidiært_dager': 15, 'betinget': 'delvis', 'fengsel_dager_betinget': 60, 'bot': 5000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §10']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Straffeloven §155'], ['Straffeloven §202'], ['Straffeloven §371'], ['Straffeloven §231'], ['Straffeloven §342'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §323', ['Straffeloven §321']], ['Straffeloven §79']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 120}, 'dømt': [['Straffeloven §273'], ['Straffeloven §155']]}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 150}, 'dømt': [['Straffeloven §155'], ['Straffeloven §321', ['Straffeloven §15']], ['Straffeloven §266'], ['Straffeloven §342'], ['Straffeloven §351'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §181'], ['Vegtrafikkloven §31'], ['Straffeloven §168'], ['Straffeloven §271'], ['Straffeloven §323', ['Straffeloven §321']], ['Straffeloven §353', ['Straffeloven §351']], ['Straffeloven §190', ['Våpenloven §7']], ['Straffeloven §263'], ['Vegtrafikkloven §24', ['Vegtrafikkloven §33']]], 'frifunnet': [['Straffeloven §321', ['Straffeloven §15']], ['Straffeloven §168'], ['Straffeloven §321']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 100}, 'dømt': [['Straffeloven §272', ['Straffeloven §271']], ['Straffeloven §231'], ['Straffeloven §321'], ['Straffeloven §351'], ['Straffeloven §189'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 240, 'betinget': 'delvis', 'fengsel_dager_betinget': 120}, 'dømt': [['Legemiddelloven §31', ['Legemiddelloven §24', 'Straffeloven §79']], ['Straffeloven §80']]}]
# [{'funksjon': 'motpart', 'straff': {'forvaring': 'true'}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 510, 'betinget': 'delvis', 'fengsel_dager_betinget': 330}, 'dømt': [['Straffeloven §286'], ['Straffeloven §273'], ['Straffeloven §266'], ['Straffeloven §181'], ['Straffeloven §168'], ['Straffeloven §351'], ['Straffeloven §263'], ['Jernbaneloven §22', ['Jernbaneloven §9']], ['Straffeloven §82'], ['Straffeloven §39']], 'frifunnet': [['Jernbaneloven §22', ['Jernbaneloven §9']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 19, 'betinget': 'true'}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Straffeloven §34'], ['Vegtrafikkloven §33']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 30}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 3330}, 'dømt': [['Straffeloven §232', ['Straffeloven §231']], ['Straffeloven §333', ['Straffeloven §332']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60, 'betinget': 'true'}}]
# [{'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 810}, 'dømt': [['Straffeloven §322', ['Straffeloven §321', 'Straffeloven §15']], ['Straffeloven §322', ['Straffeloven §321', 'Straffeloven §16']], ['Straffeloven §83']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 810}, 'dømt': [['Straffeloven §322', ['Straffeloven §321', 'Straffeloven §15']], ['Straffeloven §322', ['Straffeloven §321', 'Straffeloven §16']], ['Straffeloven §83']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 810}, 'dømt': [['Straffeloven §322', ['Straffeloven §321', 'Straffeloven §15']], ['Straffeloven §322', ['Straffeloven §321', 'Straffeloven §16']], ['Straffeloven §83']]}]
# [{'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 30, 'samfunnsstraff_gjennomføringstid_dager': 120}, 'dømt': [['Straffelova §271']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 180}, 'dømt': [['Straffeloven §274', ['Straffeloven §273']], ['Våpenloven §39', ['Våpenloven §5']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 420}, 'dømt': [['Straffeloven §232', ['Straffeloven §231']]]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 15, 'bot': 40000}}]
# [{'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 270, 'samfunnsstraff_gjennomføringstid_dager': 270}, 'dømt': [['Straffeloven §327'], ['Straffeloven §351', ['Straffeloven §79']], ['Straffeloven §82']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'bot': 600000}, 'dømt': [['Våpenloven §33', ['Våpenloven §27', 'Straffeloven §27']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 360, 'fengsel_subsidiært_dager': 5}}]
# []
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 180}, 'dømt': [['Straffeloven §196']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 3960}}, {'funksjon': 'motpart'}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 3960}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 3960}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 3960}}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'fengsel_subsidiært_dager': 15, 'bot': 15000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Straffeloven §353', ['Straffeloven §351']], ['Straffeloven §79'], ['Vegtrafikkloven §33']]}]
# [{'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60, 'betinget': 'true'}, 'dømt': [['Straffeloven §273']]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §273']], 'frifunnet': [['Våpenloven §33', ['Våpenloven §8']]]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18, 'betinget': 'true'}, 'dømt': [['Straffeloven §271']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18}, 'dømt': [['Straffeloven §280'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18, 'samfunnsstraff_timer': 30, 'samfunnsstraff_gjennomføringstid_dager': 120}}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §65', ['Straffeloven §62']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 270}, 'dømt': []}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 25}, 'dømt': [['Straffeloven §271']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'fengsel_subsidiært_dager': 15, 'bot': 5000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 180}, 'dømt': [['Dyrevelferdsloven §37'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60, 'betinget': 'delvis'}, 'dømt': [['Straffeloven §271'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 14, 'betinget': 'true'}, 'dømt': [['Straffeloven §155'], ['Straffeloven §263']], 'frifunnet': ['true']}]
# []
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 24, 'fengsel_subsidiært_dager': 15, 'bot': 12000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']]]}]
# [{'funksjon': 'motpart', 'straff': {'betinget': 'delvis'}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 360, 'samfunnsstraff_timer': 300, 'samfunnsstraff_gjennomføringstid_dager': 360}, 'dømt': [['Straffeloven §281'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']]]}, {'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 240, 'samfunnsstraff_timer': 240, 'samfunnsstraff_gjennomføringstid_dager': 360}, 'dømt': [['Straffeloven §281', ['Straffeloven §15']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22', 'Straffeloven §15']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3', 'Straffeloven §15']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §5', 'Skiltforskriften §8']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1050}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 1050}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 1050}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1440}, 'dømt': [['Straffeloven §232', ['Straffeloven §231']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 360}, 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §15']]]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 360}}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 90, 'betinget': 'true'}, 'dømt': [['Straffeloven §311']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60}, 'dømt': [['Straffeloven §270'], ['Straffeloven §372', ['Straffeloven §371']], ['Straffeloven §166'], ['Straffeloven §221']]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §300', ['Straffeloven §299']]]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §157'], ['Straffeloven §155'], ['Straffeloven §156'], ['Straffeloven §263'], ['Straffeloven §266'], ['Straffeloven §168'], ['Straffeloven §271'], ['Åndsverkloven §79', ['Åndsverkloven §104']], ['Straffeloven §351'], ['Straffeloven §189'], ['Straffeloven §323', ['Straffeloven §321']], ['Straffeloven §353', ['Straffeloven §351']], ['Straffeloven §62']], 'frifunnet': []}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §266'], ['Straffeloven §60']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 14, 'betinget': 'true'}, 'dømt': [['Vegtrafikkloven §31']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 120, 'samfunnsstraff_timer': 120, 'samfunnsstraff_gjennomføringstid_dager': 360}, 'dømt': [['Straffeloven §79']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 90, 'betinget': 'true'}, 'dømt': [['Straffeloven §272', ['Straffeloven §271', 'Straffeloven §15']], ['Straffeloven §231'], ['Straffeloven §263', ['Straffeloven §15']], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §156']]}, {'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 180, 'samfunnsstraff_gjennomføringstid_dager': 360}, 'dømt': [['Straffeloven §272', ['Straffeloven §271', 'Straffeloven §15']], ['Straffeloven §327', ['Straffeloven §15']], ['Straffeloven §263', ['Straffeloven §15']], ['Straffeloven §79']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60}, 'dømt': [['Straffeloven §231']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 45, 'samfunnsstraff_timer': 44, 'samfunnsstraff_gjennomføringstid_dager': 90}, 'dømt': [['Straffeloven §271'], ['Straffeloven §181'], ['Straffeloven §156', ['Straffeloven §79']]]}]
# [{'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 180, 'bot': 10000}, 'dømt': []}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1290}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 1290}}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 330}, 'dømt': [['Utlendingsloven §108']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 15, 'betinget': 'delvis'}, 'dømt': [['Straffeloven §265'], ['Straffeloven §231'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §263'], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §156'], ['Straffeloven §37']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 100}, 'dømt': [['Straffeloven §168'], ['Straffeloven §231']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 900}, 'dømt': [['Straffeloven §232', ['Straffeloven §231']]], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Straffeloven §366'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §351'], ['Legemiddelloven §31', ['Legemiddelloven §24', 'Straffeloven §79']], ['Vegtrafikkloven §24']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 40, 'fengsel_subsidiært_dager': 10, 'betinget': 'true'}, 'dømt': [['Straffeloven §266'], ['Straffeloven §168']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21, 'betinget': 'true'}, 'dømt': [['Vegtrafikkloven §31'], ['Straffeloven §181'], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 45}, 'dømt': [['Straffeloven §361'], ['Utlendingsloven §108', ['Utlendingsloven §55']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 180}, 'dømt': [['Straffeloven §231'], ['Straffeloven §67'], ['Straffeloven §69']]}, {'funksjon': 'motpart', 'frifunnet': ['true']}]
# []
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 480}, 'dømt': [['Straffeloven §327'], ['Straffeloven §157'], ['Straffeloven §155'], ['Straffeloven §263'], ['Straffeloven §189'], ['Straffeloven §231'], ['Straffeloven §79'], ['Straffeloven §69'], ['Straffeloven §70']], 'frifunnet': [['Straffeloven §327'], ['Straffeloven §263'], ['Straffeloven §189'], ['Straffeloven §321'], ['Straffeloven §342'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'fengsel_subsidiært_dager': 45}, 'dømt': [['Tolloven §16']]}, {'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 24, 'samfunnsstraff_timer': 30, 'samfunnsstraff_gjennomføringstid_dager': 120}, 'dømt': [['Tolloven §16']], 'frifunnet': [['Tolloven §16']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'fengsel_subsidiært_dager': 45}, 'dømt': [['Tolloven §16']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 180}, 'dømt': [['Tolloven §16'], ['Straffeloven §69']], 'frifunnet': [['Alkoholloven §10']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 25, 'betinget': 'true'}, 'dømt': [['Straffeloven §271']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 150, 'betinget': 'true', 'bot': 10000}, 'dømt': [['Straffeloven §268'], ['Straffeloven §342'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §17']], ['Straffeloven §361'], ['Straffeloven §231'], ['Straffeloven §321'], ['Straffeloven §189'], ['Straffeloven §79'], ['Straffeloven §82'], ['Straffeloven §82'], ['Vegtrafikkloven §33'], ['Straffeloven §82']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'forvaring': 'true'}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 150}, 'dømt': [['Straffeloven §311']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 45}, 'dømt': [['Straffeloven §272', ['Straffeloven §271']], ['Straffeloven §34'], ['Straffeloven §37']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 45}, 'dømt': [['Straffeloven §272', ['Straffeloven §271']], ['Straffeloven §34'], ['Straffeloven §37']], 'frifunnet': ['true']}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 60}, 'dømt': [['Straffeloven §272', ['Straffeloven §271']], ['Straffeloven §271'], ['Straffeloven §79'], ['Straffeloven §34'], ['Straffeloven §37']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 45, 'betinget': 'delvis'}, 'dømt': [['Straffeloven §271'], ['Straffeloven §263'], ['Straffeloven §266'], ['Straffeloven §34'], ['Straffeloven §37']]}]
# [{'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18}, 'dømt': [['Straffeloven §155']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §231']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 24}, 'dømt': [['Straffeloven §263'], ['Straffeloven §266']]}]
# [{'funksjon': 'motpart', 'straff': {'bot': 12000}, 'dømt': [['Straffeloven §271'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 15}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Vegtrafikkloven §24']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 360}, 'dømt': [['Straffeloven §282'], ['Legemiddelloven §31', ['Legemiddelloven §24']]], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 75, 'betinget': 'true', 'fengsel_subsidiært_dager': 20, 'bot': 20000}, 'dømt': [['Straffeloven §311'], ['Straffeloven §265']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 14, 'fengsel_subsidiært_dager': 28}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 14, 'fengsel_subsidiært_dager': 28}}]
# [{'funksjon': 'motpart', 'straff': {'forvaring': 'true'}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 180, 'samfunnsstraff_timer': 150, 'samfunnsstraff_gjennomføringstid_dager': 180}, 'dømt': [['Straffeloven §264', ['Straffeloven §263', 'Straffeloven §15']], ['Straffeloven §268', ['Straffeloven §15']], ['Straffeloven §251', ['Straffeloven §15']], ['Straffeloven §189', ['Straffeloven §79']], ['Straffeloven §48'], ['Straffeloven §49'], ['Straffeloven §82'], ['Straffeloven §69', ['Straffeloven §75']]], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 210}, 'dømt': [['Straffeloven §295']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 360}, 'dømt': [['Straffeloven §271'], ['Straffeloven §263'], ['Straffeloven §168'], ['Straffeloven §155'], ['Straffeloven §342'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Straffeloven §79']], 'frifunnet': [['Straffeloven §371'], ['Straffeloven §268', ['Straffeloven §16']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18, 'betinget': 'delvis'}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §10']], ['Vegtrafikkloven §31'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 150}, 'dømt': [['Straffeloven §302']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60, 'betinget': 'true'}, 'dømt': [['Straffeloven §273']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 25, 'fengsel_subsidiært_dager': 15}, 'dømt': [['Vegtrafikkloven §31']]}]
# [{'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 30, 'samfunnsstraff_gjennomføringstid_dager': 120}, 'dømt': [['Straffeloven §155']]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §327', ['Straffeloven §15']]]}, {'funksjon': 'motpart', 'dømt': [['Straffeloven §327'], ['Straffeloven §15']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 180}, 'dømt': [['Straffeloven §390'], ['Straffeloven §266'], ['Straffeloven §266'], ['Straffeloven §271'], ['Straffeloven §168'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 120, 'betinget': 'true'}, 'dømt': [['Straffeloven §311'], ['Straffeloven §266'], ['Straffeloven §79']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 120, 'betinget': 'true'}, 'dømt': [['Straffeloven §311'], ['Straffeloven §266'], ['Straffeloven §79']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 100}, 'dømt': [['Straffeloven §271'], ['Straffeloven §181'], ['Straffeloven §222'], ['Straffeloven §162'], ['Straffeloven §156'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'bot': 10000}, 'dømt': [['Vegtrafikkloven §22', ['Vegtrafikkloven §31']], ['Vegtrafikkloven §33']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 32}, 'dømt': [['Straffeloven §155']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 270, 'betinget': 'delvis', 'fengsel_dager_betinget': 90}, 'dømt': [['Straffeloven §168'], ['Straffeloven §263'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21, 'betinget': 'delvis'}, 'dømt': [['Straffeloven §155']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60}, 'dømt': [['Straffeloven §271'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 930}, 'dømt': [['Straffeloven §292', ['Straffeloven §291', 'Straffeloven §16']], ['Straffeloven §268'], ['Straffeloven §321']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'betinget': 'true'}, 'dømt': [['Straffeloven §155'], ['Straffeloven §353'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21, 'betinget': 'true'}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 24, 'fengsel_subsidiært_dager': 15, 'bot': 5000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 15, 'fengsel_subsidiært_dager': 20, 'betinget': 'true', 'bot': 10000}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 15, 'fengsel_subsidiært_dager': 20, 'betinget': 'true', 'bot': 10000}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18, 'fengsel_subsidiært_dager': 15, 'betinget': 'true', 'bot': 10000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §33']]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §231', ['Straffeloven §15']], ['Straffeloven §231'], ['Straffeloven §79'], ['Straffeloven §234']]}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 90}, 'dømt': [['Straffeloven §231'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'forvaring': 'true'}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 17, 'bot': 16500}, 'dømt': [['Politiloven §30'], ['Straffeloven §181'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 75, 'betinget': 'true'}, 'dømt': [['Straffeloven §231']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18, 'fengsel_subsidiært_dager': 20, 'betinget': 'true', 'bot': 15000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §5', 'Skiltforskriften §8']]]}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18}, 'dømt': [['Straffeloven §155'], ['Straffeloven §79'], ['Straffeloven §34'], ['Straffeloven §37']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 16, 'betinget': 'delvis'}, 'dømt': [['Straffeloven §231'], ['Straffeloven §189'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 2160}, 'dømt': [['Straffeloven §232', ['Straffeloven §231']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §5', 'Skiltforskriften §8']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §17']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 120}, 'dømt': [['Straffeloven §321'], ['Straffeloven §351'], ['Straffeloven §271'], ['Politiloven §30']], 'motpart_id': ''}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 120}, 'dømt': [['Straffeloven §322', ['Straffeloven §321']], ['Straffeloven §321'], ['Straffeloven §343'], ['Straffeloven §323', ['Straffeloven §321']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 8, 'bot': 4000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §323'], ['Straffeloven §373', ['Straffeloven §371']], ['Straffeloven §79']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60, 'betinget': 'delvis'}, 'dømt': [['Straffeloven §272'], ['Straffeloven §37']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 150, 'betinget': 'delvis', 'fengsel_dager_betinget': 60}, 'dømt': [['Straffeloven §202'], ['Straffeloven §271'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §273'], ['Straffeloven §79']], 'frifunnet': []}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 720}, 'dømt': [['Straffeloven §219'], ['Straffeloven §282']], 'frifunnet': []}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 90, 'fengsel_subsidiært_dager': 15}}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §263'], ['Straffeloven §187'], ['Straffeloven §156'], ['Straffeloven §168'], ['Straffeloven §78']], 'frifunnet': [['Straffeloven §263']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1980}, 'dømt': [['Straffeloven §299'], ['Straffeloven §302'], ['Straffeloven §304'], ['Straffeloven §311'], ['Straffeloven §309'], ['Straffeloven §316'], ['Straffeloven §306']], 'frifunnet': []}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'fengsel_subsidiært_dager': 15, 'bot': 45000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Legemiddelloven §31', ['Legemiddelloven §24']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 2880}, 'dømt': [['Straffeloven §232']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'fengsel_subsidiært_dager': 15, 'bot': 50000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 120}, 'dømt': [['Straffeloven §352', ['Straffeloven §351']], ['Straffeloven §155'], ['Straffeloven §351'], ['Straffeloven §189'], ['Legemiddelloven §31', ['Legemiddelloven §24']]]}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart'}, {'funksjon': 'motpart'}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18, 'fengsel_subsidiært_dager': 15, 'bot': 10000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §79'], ['Vegtrafikkloven §33']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 270}, 'dømt': [['Straffeloven §299'], ['Straffeloven §311'], ['Straffeloven §79'], ['Straffeloven §299'], ['Straffeloven §311'], ['Straffeloven §79']], 'frifunnet': []}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 180}, 'dømt': []}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 180, 'betinget': 'true'}, 'dømt': [['Straffeloven §327', ['Straffeloven §15']], ['Straffeloven §189'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 45}, 'dømt': [['Straffeloven §221'], ['Straffeloven §361']]}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 960}, 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §15']], ['Utlendingsloven §108', ['Utlendingsloven §124']], ['Legemiddelloven §31', ['Legemiddelloven §13']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 14, 'betinget': 'true', 'fengsel_subsidiært_dager': 15}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Straffeloven §231'], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Vegtrafikkloven §33']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 720, 'betinget': 'delvis', 'fengsel_dager_betinget': 180}, 'dømt': [['Straffeloven §232', ['Straffeloven §231']], ['Straffeloven §231'], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §31'], ['Straffeloven §268'], ['Straffeloven §332'], ['Straffeloven §326'], ['Straffeloven §351'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §17']], ['Straffeloven §189'], ['Straffeloven §79'], ['Straffeloven §69'], ['Straffeloven §75']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21, 'bot': 4000}, 'dømt': [['Straffeloven §231']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60, 'betinget': 'true'}, 'dømt': [['Straffeloven §155']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1440}, 'dømt': [['Straffeloven §322', ['Straffeloven §321', 'Straffeloven §15']]], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 70}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18, 'fengsel_subsidiært_dager': 15, 'betinget': 'true', 'bot': 10000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 19, 'bot': 19200}, 'dømt': [['Straffeloven §168']]}]
# [{'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 30, 'samfunnsstraff_gjennomføringstid_dager': 120}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 210}, 'dømt': [['Straffeloven §273', ['Straffeloven §15']], ['Forsinkelsesrenteloven §3']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 150}, 'dømt': [['Straffeloven §273', ['Straffeloven §15']], ['Forsinkelsesrenteloven §3']]}]
# []
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60}, 'dømt': [['Straffeloven §361']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 360}, 'dømt': [['Straffeloven §299']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1800}, 'dømt': [['Straffeloven §322'], ['Utlendingsloven §108', ['Utlendingsloven §124']], ['Straffeloven §162']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 300, 'betinget': 'delvis', 'fengsel_dager_betinget': 180, 'fengsel_subsidiært_dager': 15, 'bot': 5000}, 'dømt': [['Straffeloven §321'], ['Straffeloven §231'], ['Straffeloven §332'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Straffeloven §351'], ['Straffeloven §79'], ['Straffeloven §39'], ['Straffeloven §34'], ['Straffeloven §37']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 24}, 'dømt': [['Straffeloven §155'], ['Straffeloven §156'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 24, 'fengsel_subsidiært_dager': 15, 'bot': 5000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60, 'betinget': 'delvis', 'fengsel_dager_betinget': '30'}, 'dømt': [['Straffeloven §305'], ['Straffeloven §181'], ['Politiloven §30'], ['Straffeloven §156'], ['Straffeloven §361']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60, 'betinget': 'true'}, 'dømt': [['Straffeloven §190', ['Våpenloven §8']], ['Straffeloven §190', ['Våpenloven §15', 'Våpenloven §13']], ['Våpenloven §33', ['Våpenloven §27']], ['Straffeloven §155'], ['Legemiddelloven §31', ['Legemiddelloven §25']]]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §232']]}]
# [{'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 660}, 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §15']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1260}, 'dømt': [['Straffeloven §67']]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §273']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 2040}, 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §79']], ['Tolloven §16'], ['Straffeloven §79']]}, {'funksjon': 'motpart'}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 1590}, 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §79']], ['Tolloven §16'], ['Straffeloven §79']]}, {'funksjon': 'motpart'}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 1440}, 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §79']], ['Tolloven §16'], ['Straffeloven §79']]}, {'funksjon': 'motpart'}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 1590}, 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §79']], ['Tolloven §16'], ['Straffeloven §79']]}, {'funksjon': 'motpart'}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 1230}, 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §79']], ['Tolloven §16'], ['Straffeloven §79']]}, {'funksjon': 'motpart'}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 1230}, 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §79']], ['Tolloven §16'], ['Straffeloven §79']]}, {'funksjon': 'motpart'}, {'funksjon': 'motpart'}, {'funksjon': 'motpart'}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 1230}, 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §79']], ['Tolloven §16'], ['Straffeloven §79']]}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 2880}, 'dømt': [['Straffeloven §232'], ['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §15']], ['Straffeloven §333', ['Straffeloven §232', 'Straffeloven §15']], ['Straffeloven §79']]}, {'funksjon': 'motpart'}, {'funksjon': 'motpart'}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 150}, 'dømt': [['Straffeloven §266'], ['Straffeloven §168'], ['Straffeloven §263'], ['Straffeloven §271']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 90}, 'dømt': [['Straffeloven §166'], ['Straffeloven §221']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 90, 'betinget': 'true'}, 'dømt': [['Straffeloven §273']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21, 'betinget': 'true'}, 'dømt': [['Straffeloven §231'], ['Straffeloven §271'], ['Straffeloven §371'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §10']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §79']], 'frifunnet': [['Straffeloven §323', ['Straffeloven §321']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 36, 'fengsel_subsidiært_dager': 15}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §5', 'Skiltforskriften §8']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21}, 'dømt': [['Straffeloven §155'], ['Straffeloven §181'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 300, 'betinget': 'true'}, 'dømt': [['Straffeloven §155'], ['Straffeloven §34'], ['Straffeloven §37']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 270}, 'dømt': [['Straffeloven §322', ['Straffeloven §321']]]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'fengsel_subsidiært_dager': 15, 'bot': 9000}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'fengsel_subsidiært_dager': 15, 'bot': 9000}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 15, 'betinget': 'true'}, 'dømt': [['Straffeloven §155'], ['Straffeloven §37'], ['Straffeloven §82']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart'}, {'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 240, 'fengsel_subsidiært_dager': 20, 'betinget': 'true', 'bot': 20000}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 240, 'fengsel_subsidiært_dager': 20, 'betinget': 'true', 'bot': 20000}}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'frifunnet': ['true'], 'motpart_id': ''}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 210}, 'dømt': [['Straffeloven §333', ['Straffeloven §332']]]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 90}, 'dømt': [['Straffeloven §273'], ['Straffeloven §78']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 2520}, 'dømt': [['Straffeloven §232', ['Straffeloven §231']]], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 120}, 'dømt': [['Straffeloven §221'], ['Utlendingsloven §108', ['Utlendingsloven §55']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 540}, 'dømt': [['Utlendingsloven §108']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1440}, 'dømt': [['Straffeloven §292', ['Straffeloven §291']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21, 'fengsel_subsidiært_dager': 15, 'bot': 4000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']]]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §327'], ['Straffeloven §273'], ['Straffeloven §79'], ['Straffeloven §82']]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §300', ['Straffeloven §299']], ['Straffeloven §311'], ['Straffeloven §79'], ['Straffeloven §52']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21, 'betinget': 'true'}, 'dømt': [['Straffeloven §155']]}]
# [{'funksjon': 'motpart', 'frifunnet': []}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21, 'fengsel_subsidiært_dager': 15, 'bot': 39000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §10']]]}]
# [{'funksjon': 'motpart', 'straff': {'bot': 3000}, 'dømt': [['Legemiddelloven §31', ['Legemiddelloven §24']]], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 150}, 'dømt': [['Straffeloven §322', ['Straffeloven §321', 'Straffeloven §15']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 360}, 'dømt': [['Utlendingsloven §108']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 180}, 'dømt': [['Straffeloven §273'], ['Straffeloven §155']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 150, 'fengsel_subsidiært_dager': 6}, 'dømt': [['Straffeloven §231'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §79'], ['Vegtrafikkloven §33']]}]
# [{'funksjon': 'motpart', 'frifunnet': []}, {'funksjon': 'motpart', 'frifunnet': ['true']}, {'funksjon': 'motpart', 'frifunnet': []}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 90}, 'dømt': [['Straffeloven §322', ['Straffeloven §321', 'Straffeloven §15']]]}]
# [{'funksjon': 'motpart'}]
# []
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60, 'betinget': 'true'}, 'dømt': [['Straffeloven §263'], ['Straffeloven §189'], ['Straffeloven §155'], ['Straffeloven §321'], ['Straffeloven §271', ['Straffeloven §15']], ['Straffeloven §351'], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §156'], ['Straffeloven §353', ['Straffeloven §351']], ['Straffeloven §162']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 540}, 'dømt': [['Straffeloven §192']], 'motpart_id': ''}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60}, 'dømt': [['Straffeloven §361', ['Straffeloven §16']], ['Utlendingsloven §108', ['Utlendingsloven §55']]]}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 18, 'samfunnsstraff_timer': 45, 'samfunnsstraff_gjennomføringstid_dager': 120}, 'dømt': [['Straffeloven §286'], ['Straffeloven §156'], ['Straffeloven §79']]}]
# ...
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 30, 'samfunnsstraff_gjennomføringstid_dager': 90}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §5', 'Skiltforskriften §8']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §5']]]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §272', ['Straffeloven §271', 'Straffeloven §15']], ['Straffeloven §327'], ['Straffeloven §155'], ['Straffeloven §271'], ['Straffeloven §327', ['Straffeloven §15']], ['Straffeloven §156']]}]
# [{'funksjon': 'motpart', 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §5', 'Skiltforskriften §8']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 180}, 'dømt': [['Straffeloven §273']]}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 75}, 'dømt': [['Straffeloven §272', ['Straffeloven §271']], ['Straffeloven §271']]}]
# [{'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 120, 'samfunnsstraff_gjennomføringstid_dager': 180}, 'dømt': [['Straffeloven §273']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21, 'fengsel_subsidiært_dager': 15, 'betinget': 'true'}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §17']], ['Legemiddelloven §31', ['Legemiddelloven §24']]]}]
# [{'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 30, 'samfunnsstraff_gjennomføringstid_dager': 90}, 'dømt': [['Straffeloven §155']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60}, 'dømt': [['Straffeloven §155'], ['Politiloven §30']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 75, 'samfunnsstraff_timer': 75, 'samfunnsstraff_gjennomføringstid_dager': 180}, 'dømt': [['Straffeloven §311']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18, 'fengsel_subsidiært_dager': 15, 'bot': 7500}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22', 'Straffeloven §79']]]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 240}, 'dømt': [['Straffeloven §272', ['Straffeloven §271']], ['Straffeloven §271'], ['Straffeloven §263'], ['Straffeloven §155']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 210}, 'dømt': [['Straffeloven §302']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18}, 'dømt': [['Straffeloven §155']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1920}, 'dømt': [['Straffeloven §274'], ['Straffeloven §273', ['Straffeloven §16']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60}, 'dømt': [['Utlendingsloven §108']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 75}, 'dømt': [['Straffeloven §271']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 15, 'bot': 30000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §79'], ['Vegtrafikkloven §33']]}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §15']]]}, {'funksjon': 'motpart', 'dømt': [['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21}, 'dømt': [['Straffeloven §371'], ['Straffeloven §221', ['Straffeloven §79']]], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 450}, 'dømt': [['Utlendingsloven §108', ['Utlendingsloven §55']], ['Utlendingsloven §108']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21, 'betinget': 'true'}, 'dømt': [['Straffeloven §231']], 'frifunnet': []}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 1530}, 'dømt': [['Straffeloven §292']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 330}, 'dømt': [['Straffeloven §262', ['Straffeloven §15']]]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 330}, 'dømt': [['Straffeloven §262', ['Straffeloven §15']], ['Straffeloven §311']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 330}, 'dømt': [['Straffeloven §262', ['Straffeloven §15']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 360}, 'dømt': [['Straffeloven §327'], ['Straffeloven §155'], ['Straffeloven §342'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Straffeloven §263'], ['Straffeloven §168'], ['Straffeloven §351', ['Straffeloven §15']], ['Straffeloven §351'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §189'], ['Straffeloven §323', ['Straffeloven §321']], ['Straffeloven §79'], ['Straffeloven §82'], ['Straffeloven §52']], 'frifunnet': [['Politiloven §30']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 90, 'betinget': 'true'}, 'dømt': [['Straffeloven §322', ['Straffeloven §321']], ['Straffeloven §372', ['Straffeloven §371']], ['Straffeloven §371'], ['Straffeloven §342'], ['Straffeloven §361'], ['Straffeloven §321'], ['Matloven §28', ['Matloven §33', 'Såvareforskriften §39']]], 'frifunnet': [['Straffeloven §202']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60}, 'dømt': [['Luftfartsloven §14']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'dømt': [['Tolloven §16']]}]
# []
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18}, 'dømt': [['Straffeloven §155']]}]
# [{'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 16, 'samfunnsstraff_timer': 30, 'samfunnsstraff_gjennomføringstid_dager': 120}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §5', 'Skiltforskriften §8']]]}]
# [{'funksjon': 'motpart', 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §3']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §79']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 660}, 'dømt': [['Straffeloven §327', ['Straffeloven §15']], ['Straffeloven §271'], ['Straffeloven §231'], ['Straffeloven §189'], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §79'], ['Straffeloven §82'], ['Straffeloven §39']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 270, 'betinget': 'true'}}, {'funksjon': 'motpart', 'dømt': [['Straffeloven §327', ['Straffeloven §15']], ['Straffeloven §231'], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'betinget': 'true'}, 'dømt': [['Straffeloven §371'], ['Straffeloven §79']], 'frifunnet': [['Straffeloven §371']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 45}, 'dømt': [['Straffeloven §311'], ['Straffeloven §267'], ['Straffeloven §79'], ['Straffeloven §34']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 360}, 'dømt': [['Straffeloven §291'], ['Straffeloven §302'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 540}, 'dømt': [['Straffeloven §232', ['Straffeloven §231', 'Straffeloven §15']], ['Straffeloven §263'], ['Straffeloven §231', ['Straffeloven §15']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 26, 'fengsel_subsidiært_dager': 15, 'betinget': 'true', 'bot': 37500}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']]]}]
# [{'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 168, 'samfunnsstraff_gjennomføringstid_dager': 180}, 'dømt': [['Straffeloven §273'], ['Straffeloven §189'], ['Straffeloven §79']]}, {'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 70, 'samfunnsstraff_gjennomføringstid_dager': 180}, 'dømt': [['Straffeloven §272', ['Straffeloven §271', 'Straffeloven §15']]]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 90}, 'dømt': [['Straffeloven §272', ['Straffeloven §271', 'Straffeloven §15']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 32}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §24']]], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 14, 'fengsel_subsidiært_dager': 15, 'betinget': 'true', 'bot': 15000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Straffeloven §34']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 24, 'fengsel_subsidiært_dager': 15, 'bot': 7000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 24, 'fengsel_subsidiært_dager': 15}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60}}, {'funksjon': 'motpart'}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 60}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 24, 'fengsel_dager': 14, 'bot': 24000}, 'dømt': [['Vegtrafikkloven §31']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 75}, 'dømt': [['Straffelova §325', ['Straffelova §324']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 14, 'fengsel_subsidiært_dager': 15, 'betinget': 'true', 'bot': 50000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']]]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 60, 'betinget': 'true'}, 'dømt': [['Straffeloven §155'], ['Straffeloven §156'], ['Straffeloven §271'], ['Straffeloven §263'], ['Straffeloven §162'], ['Straffeloven §351'], ['Straffeloven §82'], ['Straffeloven §69', ['Straffeloven §71', 'Straffeloven §75']]], 'frifunnet': [['Straffeloven §271']]}]
# []
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 720}}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 720}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 360}, 'dømt': [['Straffeloven §232'], ['Vareførselsloven §12'], ['Straffeloven §79'], ['Vegtrafikkloven §33']], 'frifunnet': [['Vegtrafikkloven §31', ['Vegtrafikkloven §23']]]}]
# [{'funksjon': 'motpart', 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 930}, 'dømt': [['Straffeloven §232', ['Straffeloven §231']], ['Straffeloven §155'], ['Straffeloven §266'], ['Straffeloven §231'], ['Straffeloven §263'], ['Straffeloven §168'], ['Straffeloven §189'], ['Straffeloven §351']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18}, 'dømt': [['Straffeloven §263']]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 210, 'samfunnsstraff_timer': 210, 'samfunnsstraff_gjennomføringstid_dager': 210}, 'dømt': [['Straffeloven §327', ['Straffeloven §15']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 120, 'betinget': 'true'}, 'dømt': [['Straffeloven §273'], ['Straffeloven §37']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18, 'betinget': 'true'}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §6']]]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18, 'betinget': 'true'}, 'dømt': [['Straffeloven §263']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 150}, 'dømt': []}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 90, 'betinget': 'delvis', 'fengsel_dager_betinget': '90'}, 'dømt': [['Straffeloven §272', ['Straffeloven §271', 'Straffeloven §15']]]}, {'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 150}, 'dømt': [['Straffeloven §272', ['Straffeloven §271', 'Straffeloven §15']], ['Straffeloven §272', ['Straffeloven §271']], ['Straffeloven §263'], ['Straffeloven §79']]}, {'funksjon': 'motpart', 'straff': {'fengsel_subsidiært_dager': 150, 'samfunnsstraff_timer': 150, 'samfunnsstraff_gjennomføringstid_dager': 300}, 'dømt': [['Straffeloven §272', ['Straffeloven §271', 'Straffeloven §15']], ['Straffeloven §231'], ['Våpenloven §39', ['Våpenloven §8', 'Våpenloven §41']], ['Straffeloven §79'], ['Straffeloven §69'], ['Straffeloven §70']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 75, 'betinget': 'delvis'}, 'dømt': [['Straffeloven §272', ['Straffeloven §271', 'Straffeloven §15']], ['Straffeloven §34']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 75, 'betinget': 'delvis'}, 'dømt': [['Straffeloven §34']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 150, 'fengsel_subsidiært_dager': 15, 'betinget': 'true', 'bot': 5000}, 'dømt': [['Straffeloven §231'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §342']]}, {'funksjon': 'motpart', 'straff': {'fengsel_dager': 180, 'fengsel_subsidiært_dager': 15, 'bot': 10000}, 'dømt': [['Straffeloven §322', ['Straffeloven §321']], ['Straffeloven §332'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 40, 'betinget': 'delvis'}, 'dømt': [['Straffeloven §311'], ['Straffeloven §251', ['Straffeloven §16']], ['Straffeloven §271'], ['Straffeloven §351'], ['Straffeloven §263'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'betinget': 'delvis', 'fengsel_dager_betinget': '15', 'bot': 8000}, 'dømt': [['Straffeloven §231'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §5', 'Skiltforskriften §8']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Straffeloven §79'], ['Straffeloven §39'], ['Straffeloven §34']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 100, 'betinget': 'true'}, 'dømt': [['Straffeloven §155']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 21}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §6']], ['Vegtrafikkloven §33']]}]
# [{'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 35, 'samfunnsstraff_gjennomføringstid_dager': 180}, 'dømt': [['Straffeloven §231'], ['Straffeloven §189'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 22}}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 90, 'betinget': 'true'}, 'dømt': [['Straffeloven §273']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30}, 'dømt': [['Straffeloven §286'], ['Straffeloven §155'], ['Straffeloven §353', ['Straffeloven §351', 'Straffeloven §79']], ['Straffeloven §83']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 300}, 'dømt': [['Straffeloven §282', ['Straffeloven §79']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 45, 'betinget': 'delvis'}, 'dømt': [['Straffeloven §271']]}]
# [{'funksjon': 'motpart'}, {'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'straff': {'samfunnsstraff_timer': 80, 'samfunnsstraff_gjennomføringstid_dager': 120}, 'dømt': [['Straffeloven §321', ['Straffeloven §322']], ['Straffeloven §231'], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 330}, 'dømt': [['Straffeloven §155'], ['Straffeloven §168'], ['Straffeloven §263'], ['Straffeloven §321'], ['Straffeloven §321', ['Straffeloven §15']], ['Straffeloven §323', ['Straffeloven §321']], ['Straffeloven §351'], ['Straffeloven §371'], ['Straffeloven §15'], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §17']], ['Straffeloven §79'], ['Straffeloven §52']], 'frifunnet': ['true']}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 18, 'fengsel_subsidiært_dager': 15}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Vegtrafikkloven §31', ['Vegtrafikkloven §24']], ['Legemiddelloven §31', ['Legemiddelloven §24']], ['Straffeloven §79']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'fengsel_subsidiært_dager': 15, 'bot': 10000}, 'dømt': [['Vegtrafikkloven §31']]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 30, 'fengsel_subsidiært_dager': 15, 'bot': 15000}, 'dømt': [['Vegtrafikkloven §31', ['Vegtrafikkloven §22']], ['Legemiddelloven §31', ['Legemiddelloven §24']]]}]
# [{'funksjon': 'motpart'}]
# [{'funksjon': 'motpart', 'dømt': [['Straffeloven §327', ['Straffeloven §15']], ['Straffeloven §272', ['Straffeloven §271', 'Straffeloven §15']]]}]
# [{'funksjon': 'motpart', 'straff': {'fengsel_dager': 780}, 'dømt': [['Straffeloven §195'], ['Straffeloven §199'], ['Straffeloven §302'], ['Straffeloven §311']], 'frifunnet': ['true']}]
# 1203 rows have been dropped because no matching defendant was found.
# Shape (8360, 33)

# %% [markdown]
# Process Judgement Data

# %%
# Flatten the dom column
judgement_df = pd.json_normalize(data=merged_df["dom"],meta=["dømt","frifunnet","uvisst"])

# Create a dummy variable for frifunnet (aquitted) 
judgement_df["judgement_aquitted"] = judgement_df["frifunnet"].apply(
    lambda a : False if isinstance(a,float) else True)

# Create a dummy variable for uvisst (unknown) 
judgement_df["judgement_unknown"] = judgement_df["uvisst"].apply(
    lambda u : False if isinstance(u,float) else True)

# Create a dummy variable for dømt (convicted)
judgement_df["judgement_convicted"] = judgement_df["dømt"].apply(
    lambda u : False if isinstance(u,float) else True)

# Merge the dataframes 
length_before_merge = len(merged_df)
merged_df = pd.merge(merged_df, judgement_df, left_index=True, right_index=True, how='inner')
merged_df.reset_index(inplace=True,drop=True)

# Make sure no merging errors 
assert length_before_merge == len(merged_df)

# %% [markdown]
# Profesional Judges
#
# The only variable here behind function (which is always just profesional judge) is whether the profesional judge is or isn't in the majority. Note, this variable is n/a if the decision is unanimous.

# %%
def parse_judge_data(raw_judge_data:list) : 
    judge_dict = raw_judge_data[0]

    if "flertall_eller_mindretall" in judge_dict : 
        if judge_dict["flertall_eller_mindretall"] == "flertall" : 
            return "Majority"

        else : 
            return "Minority"
    
    else : 
        return None 

merged_df["judge_majority_or_minority"] = merged_df["fagdommere"].apply(parse_judge_data)

# %% [markdown]
# Indictment
#
# The sections under the indictment are in nested json of an arbitrary depth, so it's a bit tricky to unpack it all. Ultimately, we want to turn all indictment sections into dummy variables.
#
# An important note: Not all the sections in the indictment nessicairly pertain to all defendants in the case.

# %% [markdown]
# Profesional Judges

# %%
def load_profesional_judges(filename) : 
    return pd.read_json(filename)

def load_judge_to_case(filename) : 
    return pd.read_json(filename)

def parse_judge_id(id) : 
    if isinstance(id,float) : 
        return None 
    
    if len(id) == 0 :
        return None 
    
    if id == [{}] : 
        return None 
    
    if "$oid" not in id[0]['fagdommer_id'] : 
        return None 
    
    else : 
        return id[0]['fagdommer_id']["$oid"]


judge_case_df = load_judge_to_case(os.getcwd() + "/00_raw_data/hidden/lr_dommer_fagdommerid.json")
judge_df = load_profesional_judges(os.getcwd() + "/00_raw_data/hidden/lr_fagdommere.json")

judge_case_df["case_id"] = judge_case_df["_id"].apply(
    lambda id : id["$oid"]
)

judge_case_df["judge_id"] = judge_case_df["fagdommere"].apply(
    parse_judge_id
)

judge_df["judge_id"] = judge_df["_id"].apply(
    lambda id : id["$oid"]
)

# Merge our two dataframes
judge_df = pd.merge(judge_case_df,judge_df,on="judge_id",how="left")
judge_df.drop(columns=["_id_x","_id_y","fagdommere"],inplace=True)
judge_df = judge_df.add_prefix("professional_judge_")

# Merge with our main dataframe 
merged_df = pd.merge(merged_df,judge_df,left_on="_id",right_on="professional_judge_case_id",how="left")
merged_df.drop(columns=["professional_judge_case_id"],inplace=True)

# %%
"""
Recursively flatten the nested json 
"""
def flatten_judgement_sections(nested_list) -> list:
    if (isinstance(nested_list,float)) or (nested_list == None) : 
        return nested_list 

    # If the judgement is unknown it is labeled "Fant ikke ord"
    if isinstance(nested_list,str) : 
        return [nested_list]
    
    flattened_list = []
    
    for item in nested_list:
        if isinstance(item, list):
            flattened_list.extend(flatten_judgement_sections(item))
        else:
            flattened_list.append(item)

    return flattened_list

def dummify_sections(row_sections:list,section:str) -> bool : 
    if isinstance(row_sections,float) : 
        return False 
    
    elif section in row_sections : 
        return True 

    else : 
        return False 
    
# Flatten sections in tiltale (indictment)
merged_df["flattened_charges"] = merged_df["tiltale"].apply(flatten_judgement_sections)

# Explode it so we have all sections in the database in one place and take unique
section_counts = merged_df["flattened_charges"].explode().value_counts()

# Filter for all values above threshold (Note: Set to 0 for now because we want to include everything)
filtered_values = section_counts[section_counts > 0].index.tolist()

# Turn all sections with a count above the threshold into a dummy variable (For now all sections)
for section in filtered_values:
    merged_df["charged_" + section] = merged_df['flattened_charges'].apply(
         dummify_sections,args=(section,)
    ).astype(int)

# %% [markdown]
# ### Extract Aggravating and Mitigating Circumstances.

# %%
"""
Recursively flatten the nested json 
"""
def flatten_circumstances(nested_list) -> list:
    if (isinstance(nested_list,float)) or (nested_list == None) : 
        return nested_list 

    # If the judgement is unknown it is labeled "Fant ikke ord"
    if isinstance(nested_list,str) : 
        return [nested_list]
    
    flattened_list = []
    
    for item in nested_list:
        if isinstance(item, list):
            flattened_list.extend(flatten_circumstances(item))
        else:
            flattened_list.append(item)

    return flattened_list

def dummify_circumstances(row_circumstances:list,circumstance:str) -> bool : 
    if isinstance(row_circumstances,float) : 
        return False 
    
    elif circumstance in row_circumstances : 
        return True 

    else : 
        return False 


aggravating_mitigating = pd.read_json("00_raw_data/hidden/130524_judgements_mitigating_aggravating.json")

aggravating_mitigating['_id'] = aggravating_mitigating['_id'].apply(
    lambda id : id['$oid']
)

# Create boolean variable that captures whether a case has aggravating or mitigating circumstances 
aggravating_mitigating['has_aggravating'] = aggravating_mitigating['skjerpende'].apply(
    lambda agg : True if isinstance(agg,list) else False 
)

aggravating_mitigating['has_mitigating'] = aggravating_mitigating['formildende'].apply(
    lambda mit : True if isinstance(mit,list) else False 
)

# Flatten aggravating and mitigating circumstnaces 

# Flatten sections in tiltale (indictment)
aggravating_mitigating["flattened_aggravating"] = aggravating_mitigating["skjerpende"].apply(flatten_circumstances)

aggravating_mitigating['flattened_mitigating'] = aggravating_mitigating["formildende"].apply(flatten_circumstances)

aggravating_list = aggravating_mitigating["flattened_aggravating"].explode().unique().tolist()
mitigating_list = aggravating_mitigating["flattened_mitigating"].explode().unique().tolist()

for circumstance in aggravating_list:
    if isinstance(circumstance,float) : 
        continue 

    aggravating_mitigating["aggravating_" + circumstance] = aggravating_mitigating['flattened_aggravating'].apply(
         dummify_circumstances,args=(circumstance,)
    ).astype(int)

for circumstance in mitigating_list:
    if isinstance(circumstance,float) : 
        continue 

    aggravating_mitigating["mitigating_" + circumstance] = aggravating_mitigating['flattened_mitigating'].apply(
         dummify_circumstances,args=(circumstance,)
    ).astype(int)


merged_df = pd.merge(merged_df, aggravating_mitigating, on="_id")

# %% [markdown]
# Matching Defendant Data
#
# The case data contains an array called 'defendants' with some information about each defendant in the case (punishment, whether they were aquitted, etc.). For our purposes, we only want each row to have the relevant case defendant data and punishment, not the data for all the other defendants in the case.

# %%
"""
Matches the nested defendant data with the defendant matched to this row. 
"""
def match_defendant_data(row) -> dict : 
    defendant_list = row["tiltalte"]

    for defendant in defendant_list: 
        if "motpart_id" in defendant : 
            if defendant["motpart_id"]["$oid"] == row["defendant__id"] : 
                return defendant

"""
Function for flattening the nested json data related to the defendant. 
Creates two intermediate variables: convicted_raw and punishment_raw that are unpacked 
seperately 
"""
def parse_defendant_data(raw_defendent_data:dict) : 
    defendant_data = {"convicted_raw":None,
                      "defendant_aquited":None,
                      "punishment_raw":None}

    if "dømt" in raw_defendent_data : 
        defendant_data["convicted_raw"] = raw_defendent_data["dømt"]
    
    if "frifunnet" in raw_defendent_data : 
        defendant_data["defendant_aquited"] = True 
    
    if "straff" in raw_defendent_data : 
        defendant_data["punishment_raw"] = raw_defendent_data["straff"]

    return pd.Series(defendant_data)

"""
Function for unpacking them raw punishment data into a set of variables
"""
def parse_punishment_data(raw_punishment_data:dict) : 
    new_punishment_columns = {"betinget":None,
                              "fengsel_dager":None,
                              "fengsel_dager_betinget":None,
                              "fengsel_subsidiært_dager":None,
                              "bot":None,
                              "forvaring":None,
                              "amfunnsstraff_gjennomføringstid_dager":None,
                              "samfunnsstraff_timer":None}

    # Return if no punishment 
    if raw_punishment_data == None : 
        return pd.Series(new_punishment_columns)
    
    # Otherwise loop through our new columns and update them if there's a match
    for col in new_punishment_columns : 
        if col in raw_punishment_data : 
            new_punishment_columns[col] = raw_punishment_data[col]
    
    return pd.Series(new_punishment_columns)

# Find our matching defendant data and unpack it. 
merged_df["raw_matched_defendant_data"] = merged_df.apply(match_defendant_data,axis=1)
merged_df[["convicted_raw","defendant_aquitted","punishment_raw"]] = merged_df["raw_matched_defendant_data"].apply(
    parse_defendant_data
)

"""
We reuse the approach for indictments for flattening and dummifying conviction sections
"""
# Flatten sections in conviction 

merged_df.convicted_raw.fillna(value=np.nan, inplace=True)

merged_df["flattened_convictions"] = merged_df["convicted_raw"].apply(flatten_judgement_sections)

# Explode it so we have all sections in the database in one place and take unique
section_counts = merged_df["flattened_convictions"].explode().unique()

# Turn all sections with a count above the threshold into a dummy variable 
for section in section_counts:
    if isinstance(section,str) : 
        merged_df["convicted_" + section] = merged_df['flattened_convictions'].apply(
            dummify_sections,args=(section,)
        ).astype(int)

# Finally we unpack the punishment data 
merged_df[["betinget",
          "fengsel_dager",
          "fengsel_dager_betinget",
          "fengsel_subsidiært_dager",
          "bot",
          "forvaring",
          "amfunnsstraff_gjennomføringstid_dager",
          "samfunnsstraff_timer"]] = merged_df["punishment_raw"].apply(parse_punishment_data)

# %% [markdown]
# Lay Judges
#
# First we unpack the lay judge field in the case data

# %%
"""
Parse the data for the lay judge field in the case data. 
"""
def parse_lay_judges(raw_lay_data:list) -> pd.Series : 

    parsed_lay_data = []
    
    # Loop through the lay judges
    for lay_dict in raw_lay_data : 

        # Append the id field 
        if "meddommer_id" in lay_dict : 
            if "$oid" in lay_dict["meddommer_id"] : 
                parsed_lay_data.append(lay_dict["meddommer_id"]["$oid"])
        
        else : 
            parsed_lay_data.append(None)

        # Whether the lay judge is in the majority or minority 
        if "flertall_eller_mindretall" in lay_dict : 
            if lay_dict["flertall_eller_mindretall"] == "flertall" : 
                parsed_lay_data.append("Majority")
            
            else : 
                parsed_lay_data.append("Minority")
        
        else : 
            parsed_lay_data.append(None)
    
    return pd.Series(parsed_lay_data)


merged_df[["lay_judge_1","lay_judge_1_majority_or_minority","lay_judge_2","lay_judge_2_majority_or_minority"]] = merged_df["meddommere"].apply(
    parse_lay_judges
)

# %% [markdown]
# Merge Lay Judges Dataframe
#
# Finally, we merge the lay judges database into a final, merged dataframe

# %%
def load_lay_judges(file:str) -> pd.DataFrame : 
    df = pd.read_json(file)

    return df

lay_df = load_lay_judges(os.getcwd() + "/00_raw_data/hidden/lr_meddommere.json")

# Extract ID for defendants 
lay_df["_id"] = lay_df["_id"].apply(lambda id_dict: id_dict["$oid"])

# Create copies for each lay df with the correct prefix 
lay_df_1 = lay_df.copy().add_prefix("lay_1_")
lay_df_2 = lay_df.copy().add_prefix("lay_2_")

# Merge based on lay judge 1 and lay judge 2 ids
merged_df = pd.merge(merged_df, lay_df_1, left_on='lay_judge_1', right_on='lay_1__id', how='left')
merged_df = pd.merge(merged_df, lay_df_2, left_on='lay_judge_2', right_on='lay_2__id', how='left')

# %% [markdown]
# Match sections to legal groupings

# %%
def dummify_chapters(row_convictions:list,section:str) -> bool : 
    if isinstance(row_convictions,float) : 
        return False 
    
    elif section in row_convictions : 
        return True

    else : 
        return False     

penal_code = pd.read_excel("01_preprocessed_data/penal_code_key.xlsx")

# Create mapping between Chapters and Sections 
chapter_section_mapping = dict(zip(penal_code['Section Norwegian'], penal_code['Chapter']))

# Turn all Chapters into a dummy variable for convicted
for section,chapter in chapter_section_mapping.items():

    # Create dummy variables for Chapters related to charges 
    merged_df["chapter_charged_" + chapter.lower().replace(" ","_")] = merged_df['flattened_charges'].apply(
         dummify_chapters,args=(section,)
    ).astype(int)

    # Create dummy variables for Chapters related to conviction  
    merged_df["chapter_convicted_" + chapter.lower().replace(" ","_")] = merged_df['flattened_convictions'].apply(
         dummify_chapters,args=(section,)
    ).astype(int)

# Create mapping between English and Norwegian sections 
norwegian_english_mapping = dict(zip(penal_code['Section Norwegian'], penal_code['section_name']))

# Add Prefixes 
mapping_charged = {'charged_' + str(key): "charged_" + value.replace(" ","_").lower().replace(",","") \
 for key, value in norwegian_english_mapping.items()
 }

mapping_convicted = {
    'convicted_' + str(key): "convicted_" + value.replace(" ","_").lower().replace(",","") \
    for key, value in norwegian_english_mapping.items()
    }

mapping_merged = {**mapping_charged,**mapping_convicted}
merged_df.rename(columns=mapping_merged,inplace=True)

# %% [markdown]
# Remove Intermediate Columns, Rename, and then Export

# %%
# A key mapping Norwegian columns to English translations 
column_key = eval(open("00_raw_data/en_no_column_key.txt","r").read())

columns_to_drop = ["fagdommere",
                   "meddommere",
                   "tiltale",
                   "dom",
                   "tiltalte",
                   "dømt",
                   "frifunnet",
                   "uvisst",
                   "raw_matched_defendant_data",
                   "convicted_raw",
                   "punishment_raw",
                   "index"]


merged_df.reset_index(inplace=True,drop=True)
merged_df.drop(columns=columns_to_drop,inplace=True)
merged_df.rename(columns=column_key,inplace=True)

print(merged_df.shape)

merged_df.to_excel("01_preprocessed_data/hidden/preprocessed_data.xlsx",index=False)
# Out:
# (8175, 3057)
